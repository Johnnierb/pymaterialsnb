# %% [markdown]
# This was produced on google colabatory. I have left the code in so you can see how the images were uploaded.

# %% [markdown]
# #This jupyter note book is about **steels**

# %% [markdown]
# Steels have been and still are the most important group of engineering materials. They find applications in transportation, construction, tools, infratructure, and many other indutries. The properties of plain carbon steels varies with composition and processing. The diagram below shows how the tensile strength and toughness varies with composition and heat treatment.

# %% [markdown]
# This first command mounts my google drive locally.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The next code imports the picture I created last week for the tutorial.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]
image = img.imread("/content/drive/My Drive/steel images/steelsspp2.JPG")
print(image.shape)
print(image.size)
plt.imshow(image)
plt.show()
# Out:
# (709, 1274, 3)
# 2709798

# %% [markdown]
# The above figure was produced using CES on a steels data set with other images superimposed on the top and captured with a snipping tool. It was posted into my google drive and then called into with the above code.

# %% [markdown]
# Further images are called in the same way.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]
image = img.imread("/content/drive/My Drive/steel images/martensite drawings.jpg")
print(image.shape)
print(image.size)
plt.imshow(image)
plt.show()
# Out:
# (4608, 3456, 3)
# 47775744

# %% [markdown]
# The next image shows how martensite is formed

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]
image = img.imread("/content/drive/My Drive/steel images/martensiteformation.jpg")
print(image.shape)
print(image.size)
plt.imshow(image)
plt.show()
# Out:
# (481, 640, 3)
# 923520

# %% [markdown]
# Martensite is a hard phase in steels. It results in a 4.3% volume increase as shown above. Martensite can appear in a twinned form when the carbon content is high.
